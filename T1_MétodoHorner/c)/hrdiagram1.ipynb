# %% [markdown]
# ### Datos de estrellas
#
# Grafica con pylab

# %%
from pylab import scatter,xlabel,ylabel,xlim,ylim,show
from numpy import loadtxt

data = loadtxt('C:/Users/Hp/Desktop/SSF-Oto24PatriciaTitlaPerez/T1_MétodoHorner/c)/stars.dat',float)

x = data[:,0]
y = data[:,1]

scatter(x,y)
xlabel("Temperature")
ylabel("Magnitude")
xlim(0,13000)
ylim(-5,20)
show()
